# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pickle

# %%
data = pd.read_csv('heart_disease_data (1).csv')

# %%
data.isnull().sum()
# Out:
# age                                                    0
# sex                                                    0
# chest pain                                             0
# resting blood pressure                                 0
# cholestoral                                            0
# Fasting blood sugar                                    0
# Resting electroCardiographic resuls                    0
# maximum heart rate achieved                            0
# exercise induced angina (1 = yes; 0 = no)              0
# ST depression induced by exercise relative to rest     0
# the slope of the peak exercise ST segment              0
# number of major vessels (0-3) colored by flourosopy    0
# thal                                                   0
# target                                                 0
# dtype: int64

# %%
x = data.drop(['target'], axis = 1)
x
# Out:
#      age  sex  chest pain  resting blood pressure  cholestoral  \
# 0     63    1           3                     145          233
# 1     37    1           2                     130          250
# 2     41    0           1                     130          204
# 3     56    1           1                     120          236
# 4     57    0           0                     120          354
# ..   ...  ...         ...                     ...          ...
# 298   57    0           0                     140          241
# 299   45    1           3                     110          264
# 300   68    1           0                     144          193
# 301   57    1           0                     130          131
# 302   57    0           1                     130          236
#
#      Fasting blood sugar  Resting electroCardiographic resuls  \
# 0                      1                                    0
# 1                      0                                    1
# 2                      0                                    0
# 3                      0                                    1
# 4                      0                                    1
# ..                   ...                                  ...
# 298                    0                                    1
# 299                    0                                    1
# 300                    1                                    1
# 301                    0                                    1
# 302                    0                                    0
#
#      maximum heart rate achieved  exercise induced angina (1 = yes; 0 = no)  \
# 0                            150                                          0
# 1                            187                                          0
# 2                            172                                          0
# 3                            178                                          0
# 4                            163                                          1
# ..                           ...                                        ...
# 298                          123                                          1
# 299                          132                                          0
# 300                          141                                          0
# 301                          115                                          1
# 302                          174                                          0
#
#      ST depression induced by exercise relative to rest  \
# 0                                                  2.3
# 1                                                  3.5
# 2                                                  1.4
# 3                                                  0.8
# 4                                                  0.6
# ..                                                 ...
# 298                                                0.2
# 299                                                1.2
# 300                                                3.4
# 301                                                1.2
# 302                                                0.0
#
#      the slope of the peak exercise ST segment  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            2
# 4                                            2
# ..                                         ...
# 298                                          1
# 299                                          1
# 300                                          1
# 301                                          1
# 302                                          1
#
#      number of major vessels (0-3) colored by flourosopy  thal
# 0                                                    0       1
# 1                                                    0       2
# 2                                                    0       2
# 3                                                    0       2
# 4                                                    0       2
# ..                                                 ...     ...
# 298                                                  0       3
# 299                                                  0       3
# 300                                                  2       3
# 301                                                  1       3
# 302                                                  1       2
#
# [303 rows x 13 columns]

# %%
y = data.target
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
tree_local = tree.explain_local(X_test[:100], y_test[:100], name='Tree')
show(tree_local)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2052/3234728180.py in <module>
# ----> 1 tree_local = tree.explain_local(X_test[:100], y_test[:100], name='Tree')
#       2 show(tree_local)
#
# NameError: name 'tree' is not defined
